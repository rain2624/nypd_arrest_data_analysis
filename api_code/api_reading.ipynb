# %% [markdown]
# ### Reading data from api
# - This script will help me to understand about the data - if the data types are proper and other things.
# - I will also store my API keys generated for this project in .env file in the same folder where I will write this code.

# %%
import os
from dotenv import load_dotenv
import pandas as pd
from sodapy import Socrata
import datetime

# %%
load_dotenv()
# Out:
# True

# %%
api_key = os.getenv("api_token")

# %%
print(f"API Key: {api_key}")
# Out:
# API Key: gNWkcS2ktgqt23MYM4cVzYmCb

# %%
# Reading only sample data
client = Socrata("data.cityofnewyork.us", api_key)

results = client.get("8h9b-rp9u", limit=2000)

# Convert to pandas DataFrame
results_df = pd.DataFrame.from_records(results)

# %%
results_df.head()
# Out:
#   arrest_key              arrest_date pd_cd                         pd_desc  \
# 0  279738730  2023-12-31T00:00:00.000   905     INTOXICATED DRIVING,ALCOHOL
# 1  279763502  2023-12-31T00:00:00.000   779  PUBLIC ADMINISTRATION,UNCLASSI
# 2  279739169  2023-12-31T00:00:00.000   397  ROBBERY,OPEN AREA UNCLASSIFIED
# 3  279757492  2023-12-31T00:00:00.000   339  LARCENY,PETIT FROM OPEN AREAS,
# 4  279762522  2023-12-31T00:00:00.000   802  ALCOHOLIC BEVERAGE CONTROL LAW
#
#   ky_cd                       ofns_desc    law_code law_cat_cd arrest_boro  \
# 0   347  INTOXICATED & IMPAIRED DRIVING  VTL11920U2          M           Q
# 1   126         MISCELLANEOUS PENAL LAW  PL 215510B          F           B
# 2   105                         ROBBERY  PL 1601001          F           B
# 3   341                   PETIT LARCENY  PL 1552500          M           M
# 4   346  ALCOHOLIC BEVERAGE CONTROL LAW  ABC0106012          M           Q
#
#   arrest_precinct  ... x_coord_cd y_coord_cd          latitude  \
# 0             115  ...    1018842     214963  40.7566325691504
# 1              41  ...    1015482     237651          40.81892
# 2              48  ...    1015722     246426         40.843004
# 3              18  ...     990755     215975         40.759476
# 4             103  ...    1050208     199279         40.713406
#
#             longitude                                            lon_lat  \
# 0  -73.87513950341157  {'type': 'Point', 'coordinates': [-73.87513950...
# 1          -73.887162  {'type': 'Point', 'coordinates': [-73.887162, ...
# 2          -73.886251  {'type': 'Point', 'coordinates': [-73.886251, ...
# 3          -73.976517  {'type': 'Point', 'coordinates': [-73.976517, ...
# 4          -73.762077  {'type': 'Point', 'coordinates': [-73.762077, ...
#
#   :@computed_region_efsh_h5xi :@computed_region_f5dn_yrer  \
# 0                       14783                          65
# 1                       12343                           8
# 2                       11269                          35
# 3                       12419                          11
# 4                       24332                          41
#
#   :@computed_region_yeji_bk3q :@computed_region_92fq_4b7q  \
# 0                           3                           5
# 1                           5                          43
# 2                           5                          43
# 3                           4                          51
# 4                           3                          16
#
#   :@computed_region_sbqj_enih
# 0                          73
# 1                          24
# 2                          31
# 3                          10
# 4                          61
#
# [5 rows x 24 columns]

# %%
results_df.columns
# Out:
# Index(['arrest_key', 'arrest_date', 'pd_cd', 'pd_desc', 'ky_cd', 'ofns_desc',
#        'law_code', 'law_cat_cd', 'arrest_boro', 'arrest_precinct',
#        'jurisdiction_code', 'age_group', 'perp_sex', 'perp_race', 'x_coord_cd',
#        'y_coord_cd', 'latitude', 'longitude', 'lon_lat',
#        ':@computed_region_efsh_h5xi', ':@computed_region_f5dn_yrer',
#        ':@computed_region_yeji_bk3q', ':@computed_region_92fq_4b7q',
#        ':@computed_region_sbqj_enih'],
#       dtype='object')

# %%
# Drop all columns that start with ":@computed_region"
results_df = results_df.loc[:, ~results_df.columns.str.startswith(":@computed_region")]

# %%
print(results_df.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2000 entries, 0 to 1999
# Data columns (total 19 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   arrest_key         2000 non-null   object
#  1   arrest_date        2000 non-null   object
#  2   pd_cd              2000 non-null   object
#  3   pd_desc            2000 non-null   object
#  4   ky_cd              2000 non-null   object
#  5   ofns_desc          2000 non-null   object
#  6   law_code           2000 non-null   object
#  7   law_cat_cd         1997 non-null   object
#  8   arrest_boro        2000 non-null   object
#  9   arrest_precinct    2000 non-null   object
#  10  jurisdiction_code  2000 non-null   object
#  11  age_group          2000 non-null   object
#  12  perp_sex           2000 non-null   object
#  13  perp_race          2000 non-null   object
#  14  x_coord_cd         2000 non-null   object
#  15  y_coord_cd         2000 non-null   object
#  16  latitude           2000 non-null   object
#  17  longitude          2000 non-null   object
#  18  lon_lat            2000 non-null   object
# dtypes: object(19)
# memory usage: 297.0+ KB
# None

# %%
# Thus we need to convert column data types 
# Convert to numeric (integer or float as appropriate) where necessary
results_df['arrest_precinct'] = pd.to_numeric(results_df['arrest_precinct'], errors='coerce')  # Coerce errors to NaN
results_df['jurisdiction_code'] = pd.to_numeric(results_df['jurisdiction_code'], errors='coerce')
results_df['x_coord_cd'] = pd.to_numeric(results_df['x_coord_cd'], errors='coerce')
results_df['y_coord_cd'] = pd.to_numeric(results_df['y_coord_cd'], errors='coerce')
results_df['latitude'] = pd.to_numeric(results_df['latitude'], errors='coerce')
results_df['longitude'] = pd.to_numeric(results_df['longitude'], errors='coerce')
results_df['pd_cd'] = pd.to_numeric(results_df['pd_cd'], errors='coerce')
results_df['ky_cd'] = pd.to_numeric(results_df['ky_cd'], errors='coerce')

# Convert to datetime (timestamp)
results_df['arrest_date'] = pd.to_datetime(results_df['arrest_date'], errors='coerce')  # Coerce invalid dates to NaT

# %%
print(results_df.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2000 entries, 0 to 1999
# Data columns (total 19 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   arrest_key         2000 non-null   object
#  1   arrest_date        2000 non-null   datetime64[ns]
#  2   pd_cd              2000 non-null   int64
#  3   pd_desc            2000 non-null   object
#  4   ky_cd              2000 non-null   int64
#  5   ofns_desc          2000 non-null   object
#  6   law_code           2000 non-null   object
#  7   law_cat_cd         1997 non-null   object
#  8   arrest_boro        2000 non-null   object
#  9   arrest_precinct    2000 non-null   int64
#  10  jurisdiction_code  2000 non-null   int64
#  11  age_group          2000 non-null   object
#  12  perp_sex           2000 non-null   object
#  13  perp_race          2000 non-null   object
#  14  x_coord_cd         2000 non-null   int64
#  15  y_coord_cd         2000 non-null   int64
#  16  latitude           2000 non-null   float64
#  17  longitude          2000 non-null   float64
#  18  lon_lat            2000 non-null   object
# dtypes: datetime64[ns](1), float64(2), int64(6), object(10)
# memory usage: 297.0+ KB
# None

# %%
results_df.head()
# Out:
#   arrest_key arrest_date  pd_cd                         pd_desc  ky_cd  \
# 0  279738730  2023-12-31    905     INTOXICATED DRIVING,ALCOHOL    347
# 1  279763502  2023-12-31    779  PUBLIC ADMINISTRATION,UNCLASSI    126
# 2  279739169  2023-12-31    397  ROBBERY,OPEN AREA UNCLASSIFIED    105
# 3  279757492  2023-12-31    339  LARCENY,PETIT FROM OPEN AREAS,    341
# 4  279762522  2023-12-31    802  ALCOHOLIC BEVERAGE CONTROL LAW    346
#
#                         ofns_desc    law_code law_cat_cd arrest_boro  \
# 0  INTOXICATED & IMPAIRED DRIVING  VTL11920U2          M           Q
# 1         MISCELLANEOUS PENAL LAW  PL 215510B          F           B
# 2                         ROBBERY  PL 1601001          F           B
# 3                   PETIT LARCENY  PL 1552500          M           M
# 4  ALCOHOLIC BEVERAGE CONTROL LAW  ABC0106012          M           Q
#
#    arrest_precinct  jurisdiction_code age_group perp_sex  \
# 0              115                  0     18-24        M
# 1               41                  0     25-44        M
# 2               48                  1     18-24        M
# 3               18                  0     25-44        M
# 4              103                  0     25-44        F
#
#                   perp_race  x_coord_cd  y_coord_cd   latitude  longitude  \
# 0            WHITE HISPANIC     1018842      214963  40.756633 -73.875140
# 1            BLACK HISPANIC     1015482      237651  40.818920 -73.887162
# 2                     BLACK     1015722      246426  40.843004 -73.886251
# 3            WHITE HISPANIC      990755      215975  40.759476 -73.976517
# 4  ASIAN / PACIFIC ISLANDER     1050208      199279  40.713406 -73.762077
#
#                                              lon_lat
# 0  {'type': 'Point', 'coordinates': [-73.87513950...
# 1  {'type': 'Point', 'coordinates': [-73.887162, ...
# 2  {'type': 'Point', 'coordinates': [-73.886251, ...
# 3  {'type': 'Point', 'coordinates': [-73.976517, ...
# 4  {'type': 'Point', 'coordinates': [-73.762077, ...

# %% [markdown]
# **Combining eveything we did above and trying to pull data monthly**

# %%
# doing for a month 
query= "arrest_date >= '2023-12-01T00:00:00.000' AND arrest_date < '2024-01-01T00:00:00.000'"

# %%
client = Socrata("data.cityofnewyork.us", api_key)

results = client.get("8h9b-rp9u", where=query)

# Convert to pandas DataFrame
results_df = pd.DataFrame.from_records(results)

# %%
results_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 19 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   arrest_key         1000 non-null   object
#  1   arrest_date        1000 non-null   object
#  2   pd_cd              1000 non-null   object
#  3   pd_desc            1000 non-null   object
#  4   ky_cd              1000 non-null   object
#  5   ofns_desc          1000 non-null   object
#  6   law_code           1000 non-null   object
#  7   law_cat_cd         992 non-null    object
#  8   arrest_boro        1000 non-null   object
#  9   arrest_precinct    1000 non-null   object
#  10  jurisdiction_code  1000 non-null   object
#  11  age_group          1000 non-null   object
#  12  perp_sex           1000 non-null   object
#  13  perp_race          1000 non-null   object
#  14  x_coord_cd         1000 non-null   object
#  15  y_coord_cd         1000 non-null   object
#  16  latitude           1000 non-null   object
#  17  longitude          1000 non-null   object
#  18  lon_lat            1000 non-null   object
# dtypes: object(19)
# memory usage: 148.6+ KB

# %%
results_df.head()
# Out:
#   arrest_key              arrest_date pd_cd  \
# 0  278331491  2023-12-01T00:00:00.000   439
# 1  278329886  2023-12-01T00:00:00.000   259
# 2  278363923  2023-12-01T00:00:00.000   729
# 3  278323912  2023-12-01T00:00:00.000   109
# 4  278338051  2023-12-01T00:00:00.000   637
#
#                                      pd_desc ky_cd  \
# 0  LARCENY,GRAND FROM OPEN AREAS, UNATTENDED   109
# 1           CRIMINAL MISCHIEF,UNCLASSIFIED 4   351
# 2             FORGERY,ETC.,UNCLASSIFIED-FELO   113
# 3                   ASSAULT 2,1,UNCLASSIFIED   106
# 4                 HARASSMENT,SUBD 1,CIVILIAN   578
#
#                         ofns_desc    law_code law_cat_cd arrest_boro  \
# 0                   GRAND LARCENY  PL 1553001          F           K
# 1  CRIMINAL MISCHIEF & RELATED OF  PL 1450001          M           K
# 2                         FORGERY  PL 1702500          F           Q
# 3                  FELONY ASSAULT  PL 1200512          F           K
# 4                   HARRASSMENT 2  PL 2402601          V           K
#
#   arrest_precinct jurisdiction_code age_group perp_sex       perp_race  \
# 0              61                 0     25-44        M           WHITE
# 1              69                 0     25-44        F           BLACK
# 2             110                 0     25-44        M  WHITE HISPANIC
# 3              61                 0     25-44        M           WHITE
# 4              84                 0     45-64        F  WHITE HISPANIC
#
#   x_coord_cd y_coord_cd   latitude   longitude  \
# 0     995118     155708  40.594054  -73.960866
# 1    1015441     169530  40.631944  -73.887623
# 2    1024370     213199   40.75177  -73.855195
# 3     996842     159679  40.604952  -73.954651
# 4     987295     190704  40.690115  -73.989019
#
#                                              lon_lat
# 0  {'type': 'Point', 'coordinates': [-73.960866, ...
# 1  {'type': 'Point', 'coordinates': [-73.887623, ...
# 2  {'type': 'Point', 'coordinates': [-73.855195, ...
# 3  {'type': 'Point', 'coordinates': [-73.954651, ...
# 4  {'type': 'Point', 'coordinates': [-73.989019, ...

# %%
# Convert to numeric (integer or float as appropriate) where necessary
results_df['arrest_precinct'] = pd.to_numeric(results_df['arrest_precinct'], errors='coerce')  # Coerce errors to NaN
results_df['jurisdiction_code'] = pd.to_numeric(results_df['jurisdiction_code'], errors='coerce')
results_df['x_coord_cd'] = pd.to_numeric(results_df['x_coord_cd'], errors='coerce')
results_df['y_coord_cd'] = pd.to_numeric(results_df['y_coord_cd'], errors='coerce')
results_df['latitude'] = pd.to_numeric(results_df['latitude'], errors='coerce')
results_df['longitude'] = pd.to_numeric(results_df['longitude'], errors='coerce')
results_df['pd_cd'] = pd.to_numeric(results_df['pd_cd'], errors='coerce')
results_df['ky_cd'] = pd.to_numeric(results_df['ky_cd'], errors='coerce')

# Convert to datetime (timestamp)
results_df['arrest_date'] = pd.to_datetime(results_df['arrest_date'], errors='coerce')  # Coerce invalid dates to NaT

# %%
# converting this data to parquet
results_df.to_parquet('nypd_test_data.parquet', engine='pyarrow')

# %%
check_df = pd.read_parquet('nypd_test_data.parquet', engine='pyarrow')

# %%
check_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 19 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   arrest_key         1000 non-null   object
#  1   arrest_date        1000 non-null   datetime64[ns]
#  2   pd_cd              1000 non-null   int64
#  3   pd_desc            1000 non-null   object
#  4   ky_cd              1000 non-null   int64
#  5   ofns_desc          1000 non-null   object
#  6   law_code           1000 non-null   object
#  7   law_cat_cd         992 non-null    object
#  8   arrest_boro        1000 non-null   object
#  9   arrest_precinct    1000 non-null   int64
#  10  jurisdiction_code  1000 non-null   int64
#  11  age_group          1000 non-null   object
#  12  perp_sex           1000 non-null   object
#  13  perp_race          1000 non-null   object
#  14  x_coord_cd         1000 non-null   int64
#  15  y_coord_cd         1000 non-null   int64
#  16  latitude           1000 non-null   float64
#  17  longitude          1000 non-null   float64
#  18  lon_lat            1000 non-null   object
# dtypes: datetime64[ns](1), float64(2), int64(6), object(10)
# memory usage: 148.6+ KB
